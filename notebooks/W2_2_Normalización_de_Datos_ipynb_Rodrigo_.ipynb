# %% [markdown]
# W2.2_Normalización_de_Datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 🌍 URL del dataset de casos confirmados de COVID-19 en el mundo
url_covid = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"

# 🧩 Cargando el archivo sin forzar tipos de datos
df_covid = pd.read_csv(url_covid)

# 🔎 Exploración inicial del dataset
print("🔹 Dimensiones:", df_covid.shape)
print("🔹 Tipos de datos:\n", df_covid.dtypes)

# 👀 Vista rápida del contenido
print("\n🔹 Primeras filas:")
display(df_covid.head())

# ⚠️ Revisión de valores faltantes
print("\n🔹 Nulos por columna:")
display(df_covid.isnull().sum())
# Out:
# 🔹 Dimensiones: (289, 1147)
# 🔹 Tipos de datos:
#  Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# 1/22/20             int64
#                    ...
# 3/5/23              int64
# 3/6/23              int64
# 3/7/23              int64
# 3/8/23              int64
# 3/9/23              int64
# Length: 1147, dtype: object
#
# 🔹 Primeras filas:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  2/28/23  3/1/23  3/2/23  3/3/23  \
# 0        0        0        0        0  ...   209322  209340  209358  209362
# 1        0        0        0        0  ...   334391  334408  334408  334427
# 2        0        0        0        0  ...   271441  271448  271463  271469
# 3        0        0        0        0  ...    47866   47875   47875   47875
# 4        0        0        0        0  ...   105255  105277  105277  105277
#
#    3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# 0  209369  209390  209406  209436  209451  209451
# 1  334427  334427  334427  334427  334443  334457
# 2  271469  271477  271477  271490  271494  271496
# 3   47875   47875   47875   47875   47890   47890
# 4  105277  105277  105277  105277  105288  105288
#
# [5 rows x 1147 columns]
# 🔹 Nulos por columna:
# Province/State    198
# Country/Region      0
# Lat                 2
# Long                2
# 1/22/20             0
#                  ...
# 3/5/23              0
# 3/6/23              0
# 3/7/23              0
# 3/8/23              0
# 3/9/23              0
# Length: 1147, dtype: int64

# %%
# 🏷️ Renombrando columnas para que tengan nombres más limpios y consistentes
df_covid.rename(columns={
    'Province/State': 'province_state',
    'Country/Region': 'country_region',
    'Lat': 'lat',
    'Long': 'long'
}, inplace=True)

# 👁️ Mostrando una vista previa del resultado
display(df_covid.head())
# Out:
#   province_state country_region       lat       long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  2/28/23  3/1/23  3/2/23  3/3/23  \
# 0        0        0        0        0  ...   209322  209340  209358  209362
# 1        0        0        0        0  ...   334391  334408  334408  334427
# 2        0        0        0        0  ...   271441  271448  271463  271469
# 3        0        0        0        0  ...    47866   47875   47875   47875
# 4        0        0        0        0  ...   105255  105277  105277  105277
#
#    3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# 0  209369  209390  209406  209436  209451  209451
# 1  334427  334427  334427  334427  334443  334457
# 2  271469  271477  271477  271490  271494  271496
# 3   47875   47875   47875   47875   47890   47890
# 4  105277  105277  105277  105277  105288  105288
#
# [5 rows x 1147 columns]

# %%
# 🗓️ Detectando las columnas que representan fechas
date_cols = df_covid.columns[4:]

# 🔄 Reorganizando el dataset a un formato más ordenado (de ancho a largo)
df_long = df_covid.melt(
    id_vars=['province_state', 'country_region', 'lat', 'long'],
    value_vars=date_cols,
    var_name='date',
    value_name='confirmed'
)

# ⏰ Transformando las fechas al formato de tiempo real
df_long['date'] = pd.to_datetime(df_long['date'], format='%m/%d/%y')

# 🌟 Confirmando que todo salió bien y mostrando una vista rápida
print("✅ Formato largo generado correctamente:")
display(df_long.head())
# Out:
# ✅ Formato largo generado correctamente:
#   province_state country_region       lat       long       date  confirmed
# 0            NaN    Afghanistan  33.93911  67.709953 2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300 2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600 2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800 2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900 2020-01-22          0

# %%
# 🧭 Asegurando que las coordenadas sean valores numéricos válidos
df_long['lat'] = df_long['lat'].astype(float)
df_long['long'] = df_long['long'].astype(float)

# 💉 Verificando los datos de casos confirmados
# 🔹 Convertimos a números enteros
# 🔹 Eliminamos valores imposibles (negativos)
df_long['confirmed'] = pd.to_numeric(df_long['confirmed'], errors='coerce')
df_long.loc[df_long['confirmed'] < 0, 'confirmed'] = np.nan

# 🌿 Rellenamos los vacíos con ceros, solo cuando tiene sentido
df_long['confirmed'] = df_long['confirmed'].fillna(0)

# 🧾 Revisando los tipos de datos finales
print(df_long.dtypes)
# Out:
# province_state            object
# country_region            object
# lat                      float64
# long                     float64
# date              datetime64[ns]
# confirmed                float64
# dtype: object

# %%
# Instalación y carga de la librería pycountry para obtener códigos ISO-3
# !pip install pycountry
import pycountry

# Función para convertir el nombre del país en su código ISO de tres letras
def get_iso3(country):
    try:
        return pycountry.countries.lookup(country).alpha_3
    except:
        return None

# Aplicar la función a todos los registros del dataset
df_long['iso3'] = df_long['country_region'].apply(get_iso3)

# Mostrar algunos ejemplos de países con su respectivo código ISO-3
display(df_long[['country_region', 'iso3']].drop_duplicates().head(10))
# Out:
# Collecting pycountry
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 87.4 MB/s eta 0:00:00
# Installing collected packages: pycountry
# Successfully installed pycountry-24.6.1
#         country_region iso3
# 0          Afghanistan  AFG
# 1              Albania  ALB
# 2              Algeria  DZA
# 3              Andorra  AND
# 4               Angola  AGO
# 5           Antarctica  ATA
# 6  Antigua and Barbuda  ATG
# 7            Argentina  ARG
# 8              Armenia  ARM
# 9            Australia  AUS

# %%
# Verificación de coordenadas geográficas dentro del rango permitido
valid_lat = df_long['lat'].between(-90, 90)
valid_long = df_long['long'].between(-180, 180)

# Reporte de valores fuera de rango
print("Latitudes fuera de rango:", (~valid_lat).sum())
print("Longitudes fuera de rango:", (~valid_long).sum())

# Filtrado de registros inválidos
df_long = df_long[valid_lat & valid_long]

# Confirmación del resultado final
print("Registros finales:", df_long.shape)
# Out:
# Latitudes fuera de rango: 2286
# Longitudes fuera de rango: 2286
# Registros finales: (328041, 7)

# %%
# Cargar el dataset de Chipotle desde la fuente en línea
url_chipotle = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

# Lectura del archivo con separador de tabulaciones
df_chip = pd.read_csv(url_chipotle, sep='\t')

# Exploración inicial del dataset
print("Dimensiones del dataset:", df_chip.shape)
print("Tipos de datos de cada columna:")
print(df_chip.dtypes)

# Vista previa de las primeras filas
print("\nPrimeras filas del dataset:")
display(df_chip.head())

# Revisión de valores nulos por columna
print("\nValores nulos por columna:")
display(df_chip.isnull().sum())
# Out:
# Dimensiones del dataset: (4622, 5)
# Tipos de datos de cada columna:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object
#
# Primeras filas del dataset:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# Valores nulos por columna:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
# Limpieza de la columna 'item_price': eliminar el símbolo de dólar y convertir a tipo numérico
df_chip['item_price_num'] = df_chip['item_price'].replace('[\$,]', '', regex=True).astype(float)

# Asegurar que 'quantity' sea un número entero positivo
df_chip['quantity'] = df_chip['quantity'].astype(int)
df_chip = df_chip[df_chip['quantity'] > 0]

# Crear la columna 'unit_price' (equivalente al precio por unidad)
df_chip['unit_price'] = df_chip['item_price_num']

# Calcular el total por línea (precio unitario × cantidad)
df_chip['line_total'] = round(df_chip['unit_price'] * df_chip['quantity'], 2)

# Mostrar una vista previa de las columnas relevantes
display(df_chip[['item_name', 'item_price', 'quantity', 'line_total']].head())

# %%
# Estandarizar los nombres de los productos
# 🔹 Convertir a minúsculas
# 🔹 Eliminar espacios en blanco al inicio y al final
df_chip['item_name_norm'] = df_chip['item_name'].str.lower().str.strip()

# Mostrar algunos ejemplos de los nombres originales y normalizados
display(df_chip[['item_name', 'item_name_norm']].head())

# %%
# ==============================
# CARGA DEL DATASET
# ==============================
import pandas as pd
import numpy as np

url_chipotle = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
df_chip = pd.read_csv(url_chipotle, sep='\t')

# Exploración inicial
print("Dimensiones del dataset:", df_chip.shape)
print("Tipos de datos:")
print(df_chip.dtypes)
print("\nPrimeras filas:")
display(df_chip.head())
print("\nValores nulos por columna:")
display(df_chip.isnull().sum())

# ==============================
# LIMPIEZA DE PRECIOS Y CANTIDADES
# ==============================
# Limpiar item_price: eliminar $ y convertir a float
df_chip['item_price_num'] = df_chip['item_price'].replace('[\$,]', '', regex=True).astype(float)

# Asegurar que quantity sea un entero positivo
df_chip['quantity'] = df_chip['quantity'].astype(int)
df_chip = df_chip[df_chip['quantity'] > 0]

# Crear columna unit_price
df_chip['unit_price'] = df_chip['item_price_num']

# Calcular total por línea
df_chip['line_total'] = round(df_chip['unit_price'] * df_chip['quantity'], 2)

# Mostrar algunos resultados
display(df_chip[['item_name', 'item_price', 'quantity', 'line_total']].head())

# ==============================
# NORMALIZAR NOMBRES DE PRODUCTOS
# ==============================
df_chip['item_name_norm'] = df_chip['item_name'].str.lower().str.strip()
display(df_chip[['item_name', 'item_name_norm']].head())

# ==============================
# VALIDACIONES
# ==============================
# Precios negativos y cantidades inválidas
print("Precios negativos:", (df_chip['unit_price'] < 0).sum())
print("Cantidades inválidas:", (df_chip['quantity'] < 1).sum())

# Chequeo de coherencia de precios por producto
unit_price_stats = df_chip.groupby('item_name_norm')['unit_price'].agg(['mean','std']).reset_index()
display(unit_price_stats.head())

# Detección de outliers con z-score
df_chip['z_score'] = (df_chip['unit_price'] - df_chip['unit_price'].mean()) / df_chip['unit_price'].std()
outliers = df_chip[np.abs(df_chip['z_score']) > 3]

print("Outliers detectados:", len(outliers))
display(outliers[['item_name', 'unit_price', 'z_score']].head())
# Out:
# Dimensiones del dataset: (4622, 5)
# Tipos de datos:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object
#
# Primeras filas:
# <>:23: SyntaxWarning: invalid escape sequence '\$'
# <>:23: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipython-input-3003643152.py:23: SyntaxWarning: invalid escape sequence '\$'
#   df_chip['item_price_num'] = df_chip['item_price'].replace('[\$,]', '', regex=True).astype(float)
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# Valores nulos por columna:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64
#                                item_name item_price  quantity  line_total
# 0           Chips and Fresh Tomato Salsa     $2.39          1        2.39
# 1                                   Izze     $3.39          1        3.39
# 2                       Nantucket Nectar     $3.39          1        3.39
# 3  Chips and Tomatillo-Green Chili Salsa     $2.39          1        2.39
# 4                           Chicken Bowl    $16.98          2       33.96
#                                item_name  \
# 0           Chips and Fresh Tomato Salsa
# 1                                   Izze
# 2                       Nantucket Nectar
# 3  Chips and Tomatillo-Green Chili Salsa
# 4                           Chicken Bowl
#
#                           item_name_norm
# 0           chips and fresh tomato salsa
# 1                                   izze
# 2                       nantucket nectar
# 3  chips and tomatillo-green chili salsa
# 4                           chicken bowl
# Precios negativos: 0
# Cantidades inválidas: 0
#           item_name_norm       mean       std
# 0      6 pack soft drink   6.610185  0.883177
# 1          barbacoa bowl  10.187273  1.260994
# 2       barbacoa burrito   9.832418  1.139519
# 3  barbacoa crispy tacos  10.928182  2.800739
# 4    barbacoa salad bowl  10.640000  1.317616
# Outliers detectados: 47
#               item_name  unit_price   z_score
# 135  Chicken Salad Bowl       22.50  3.541506
# 213  Chicken Salad Bowl       22.50  3.541506
# 281    Steak Salad Bowl       23.78  3.842997
# 353       Steak Burrito       22.16  3.461422
# 409        Chicken Bowl       32.94  6.000547
